# %% [markdown]
# ### ✏️ Atividade Prática 1 — Sua vez de programar
#
# Na célula de código abaixo, **substitua os `...` pelos seus próprios valores** (mantenha as aspas em textos) e execute com `Ctrl+Enter`.

# %%
# Pense em UM dado real do seu dia a dia (trabalho, estudo ou vida pessoal) e complete:

meu_dado = 12             # exemplo: 8  (ou "atrasado", ou a sua situação)
minha_informacao = f"Tenho {meu_dado} anos de experiência no mercado financeiro"    # escreva, entre aspas, o dado com contexto
meu_conhecimento = "Com base em minha experiência, acredito que devo buscar novas oportunidades de crescimento profissional"    # escreva, entre aspas, a decisão que você tomaria

print(f"Dado: {meu_dado}")
print(f"Informação: {minha_informacao}")
print(f"Conhecimento: {meu_conhecimento}")
# Out:
# Dado: 12
# Informação: Tenho 12 anos de experiência no mercado financeiro
# Conhecimento: Com base em minha experiência, acredito que devo buscar novas oportunidades de crescimento profissional

# %% [markdown]
# ### ✏️ Atividade Prática 2 — Sua vez de programar
#
# Escolha **um cenário do seu trabalho, estudo ou vida pessoal** e complete o código abaixo, substituindo os `"..."` pelo seu texto.

# %%
meu_cenario = "As dificuldades em realizar a transição de carreira para análise de dados"  # descreva em poucas palavras o cenário escolhido
print("Cenário:", meu_cenario)

print("1. Coleta:", "Reunir dados de cursos, bootcamps e vagas de emprego em análise de dados")
print("2. Limpeza:", "Remover dados de vagas falsas e cursos desatualizados")
print("3. Análise:", "Identificar padrões de habilidades exigidas e lacunas de conhecimento entre candidatos e vagas")
print("4. Visualização:", "Criar gráficos e dashboards para apresentar os resultados")
print("5. Comunicação:", "Compartilhar descobertas com stakeholders e tomar decisões baseadas em dados")
# Out:
# Cenário: As dificuldades em realizar a transição de carreira para análise de dados
# 1. Coleta: Reunir dados de cursos, bootcamps e vagas de emprego em análise de dados
# 2. Limpeza: Remover dados de vagas falsas e cursos desatualizados
# 3. Análise: Identificar padrões de habilidades exigidas e lacunas de conhecimento entre candidatos e vagas
# 4. Visualização: Criar gráficos e dashboards para apresentar os resultados
# 5. Comunicação: Compartilhar descobertas com stakeholders e tomar decisões baseadas em dados

# %% [markdown]
# ## 4. Treino em Squads — Sexta-feira (Encontro 3)
#
# Esta seção é usada **em sala (ou em salas remotas/breakout)** na sexta-feira. A turma se divide em squads e cada squad recebe **um cenário diferente** dos abaixo. Em 20–25 minutos, o squad preenche o código abaixo (em um notebook compartilhado ou na máquina de um integrante) e se prepara para apresentar em até 3 minutos.
#
# ### Cenário B — E-commerce com muitas devoluções
# Uma loja online percebeu que 1 em cada 5 pedidos está sendo devolvido nos últimos 2 meses.
#
# ### Cenário C — Hospital com tempo de espera crescente
# Pacientes estão reclamando que o tempo de espera no pronto-atendimento aumentou.
#
# ### Cenário D — Indústria com quebras frequentes de máquina
# Uma fábrica percebeu que uma máquina específica está quebrando com mais frequência nos últimos meses.
#
# ### Cenário E — Prefeitura com reclamações de buracos nas ruas
# Moradores estão reclamando nas redes sociais sobre buracos nas ruas.

# %%
# Template do squad — substitua pelo cenário recebido (B, C, D ou E)

cenario_do_squad = "D — Indústria com quebras frequentes de máquina"  # cole aqui o cenário recebido
print("Cenário:", cenario_do_squad)

print("1. Coleta:", "Reunir dados de manutenção, histórico de quebras e tempo de operação da máquina")
print("2. Limpeza:", "Remover registros incompletos e corrigir datas de manutenção inconsistentes")
print("3. Análise:", "Identificar causas raiz das quebras e padrões de desempenho")
print("4. Visualização:", "Criar gráficos e dashboards para apresentar os resultados")
print("5. Comunicação:", "Compartilhar descobertas com stakeholders e tomar decisões baseadas em dados")
# Out:
# Cenário: D — Indústria com quebras frequentes de máquina
# 1. Coleta: Reunir dados de manutenção, histórico de quebras e tempo de operação da máquina
# 2. Limpeza: Remover registros incompletos e corrigir datas de manutenção inconsistentes
# 3. Análise: Identificar causas raiz das quebras e padrões de desempenho
# 4. Visualização: Criar gráficos e dashboards para apresentar os resultados
# 5. Comunicação: Compartilhar descobertas com stakeholders e tomar decisões baseadas em dados
